# %% [markdown]
# ### Ultralytics Yolov5 설치

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
import os
from IPython.display import Image, clear_output  # to display images

# %%
torch.__version__
# Out:
# '2.0.1+cu118'

# %%
# !pip freeze > requirement.txt

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 614.4/614.4 kB 2.9 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15874, done.
# remote: Counting objects: 100% (106/106), done.
# remote: Compressing objects: 100% (86/86), done.
# remote: Total 15874 (delta 45), reused 56 (delta 20), pack-reused 15768
# Receiving objects: 100% (15874/15874), 14.68 MiB | 19.48 MiB/s, done.
# Resolving deltas: 100% (10857/10857), done.

# %% [markdown]
# ### 학습 모델로 실제 이미지 test결과

# %%
# !python /content/yolov5/detect.py --weights /content/drive/MyDrive/object_detection/yolov5_32_50_l.pt --img 416 --conf 0.1 --save-txt --source /content/38.jpg
# Out:
# detect: weights=['/content/drive/MyDrive/object_detection/yolov5_32_50_l.pt'], source=/content/38.jpg, data=yolov5/data/coco128.yaml, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-203-g0897415 Python-3.10.12 torch-2.0.1+cu118 CPU
#
# Fusing layers...
# Model summary: 267 layers, 46205208 parameters, 0 gradients
# image 1/1 /content/38.jpg: 416x320 1 cabbage, 1 meat, 724.3ms
# Speed: 0.6ms pre-process, 724.3ms inference, 1.1ms NMS per image at shape (1, 3, 416, 416)
# Results saved to yolov5/runs/detect/exp5
# 1 labels saved to yolov5/runs/detect/exp5/labels

# %%
from distutils.dir_util import copy_tree
import shutil

# 복사할 폴더(/content/yolov5/runs/train)
from_file_path = '/content/yolov5/runs/detect'

# 복사 위치(/content/drive/MyDrive/object_detection) + 폴더가 저장될 폴더(/result_img)
to_file_path = '/content/drive/MyDrive/object_detection/result_picture_128_l'

shutil.copytree(from_file_path, to_file_path) # 파일을 복사하는 코드
# copy_tree(from_file_path, to_file_path) # 폴더를 복사하는 코드
# Out:
# '/content/drive/MyDrive/object_detection/result_picture_128_l'

# %%
#display inference on ALL test images

import glob
from IPython.display import Image, display

for imageName in glob.glob('/content/yolov5/runs/detect/exp/*.jpg'): #assuming JPG
    display(Image(filename=imageName))
    print("\n")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
from distutils.dir_util import copy_tree
import shutil

for num in range(1 , 36) :
  from_one = f'/content/drive/MyDrive/object_detection/result_picture_128_l/exp{num}/{num}.jpg'
  to_two = f'/content/drive/MyDrive/object_detection/result_picture_128_l/{num}.jpg'
  shutil.copyfile(from_one, to_two) # 파일을 복사하는 코드

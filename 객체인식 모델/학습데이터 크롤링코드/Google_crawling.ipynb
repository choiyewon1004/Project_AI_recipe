# %%
import pandas as pd
import numpy as np
import pandas as pd
from tqdm import tqdm

from geopy.geocoders import Nominatim
import pandas as pd
from tqdm import tqdm
from tqdm import trange
geo_local = Nominatim(user_agent='South Korea')

from bs4 import BeautifulSoup
from selenium import webdriver
import time
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# 필요한 라이브러리 불러오기
from selenium import webdriver
from urllib.request import urlopen, Request
from selenium.webdriver.common.keys import Keys
import time
import urllib.request
import os
import requests

# %%
def get_img(query_text):
    count = 261
    
    driver = webdriver.Chrome()
    driver.get("https://www.google.co.kr/imghp?hl=ko&tab=wi&authuser=0&ogbl")
    time.sleep(2) 

    elem = driver.find_element(By.CLASS_NAME,'gLFyf')
    elem.send_keys(query_text)
    elem.send_keys(Keys.RETURN)
    
#     out = driver.find_element(By.CLASS_NAME,'O3S9Rb')
#     driver.execute_script("arguments[0].click();", out)
    
    
    SCROLL_PAUSE_TIME = 1
    # Get scroll height
    last_height = driver.execute_script("return document.body.scrollHeight")

    scroll_cnt = 6
    while scroll_cnt>0:
        # Scroll down to bottom
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        # Wait to load page
        time.sleep(SCROLL_PAUSE_TIME)
        # Calculate new scroll height and compare with last scroll height
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            try:
                driver.find_element(By.CSS_SELECTOR, ".mye4qd").click()
            except:
                break
        last_height = new_height
        scroll_cnt-=1
    
    #=====================================================================


    time.sleep(4)
    img_card = driver.find_elements(By.XPATH,"//div[@jsname='DeysSe']")
    for card_idx in tqdm(img_card):
        
        try :
            card_idx.click()
            time.sleep(2)
            imgUrl = driver.find_element(By.XPATH,"//img[@jsname='kn3ccd']").get_attribute('src')
            file_path = f"{query_text}/" + query_text + "_" + str(count) + ".jpg"

            try :
                urllib.request.urlretrieve(imgUrl, file_path)
                count +=1 
            except :
                try :
                    os.system("curl " + imgUrl + " > "+file_path)   
                    count +=1 
                except:
                    count +=1 
                    continue
                
            if count == (261+260+260):
                break
        except :
            continue
        
    
        
    time.sleep(5)
    driver.close()

# %%
search = "spam"
if not os.path.isdir(f"{search}/"):
    os.makedirs(f"{search}/")
    
get_img(search)
# Out:
#   5%|████▎                                                                            | 21/400 [00:48<17:13,  2.73s/it]

# %%
def get_img(query_text):
    count = 1111111
    
    driver = webdriver.Chrome()
    driver.get("https://www.google.co.kr/imghp?hl=ko&tab=wi&authuser=0&ogbl")
    time.sleep(2) 

    elem = driver.find_element(By.CLASS_NAME,'gLFyf')
    elem.send_keys(query_text)
    elem.send_keys(Keys.RETURN)
    
#     out = driver.find_element(By.CLASS_NAME,'O3S9Rb')
#     driver.execute_script("arguments[0].click();", out)
    
    
    SCROLL_PAUSE_TIME = 1
    # Get scroll height
    last_height = driver.execute_script("return document.body.scrollHeight")

    scroll_cnt = 6
    while scroll_cnt>0:
        # Scroll down to bottom
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        # Wait to load page
        time.sleep(SCROLL_PAUSE_TIME)
        # Calculate new scroll height and compare with last scroll height
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            try:
                driver.find_element(By.CSS_SELECTOR, ".mye4qd").click()
            except:
                break
        last_height = new_height
        scroll_cnt-=1
    
    #=====================================================================


    time.sleep(4)
    img_card = driver.find_elements(By.XPATH,"//div[@jsname='DeysSe']")
    for card_idx in tqdm(img_card):
        
        try :
            card_idx.click()
            time.sleep(2)
            imgUrl = driver.find_element(By.XPATH,"//img[@jsname='kn3ccd']").get_attribute('src')
            file_path = f"{query_text}/" + query_text + "_" + str(count) + ".jpg"

            try :
                urllib.request.urlretrieve(imgUrl, file_path)
                count +=1 
            except :
                try :
                    os.system("curl " + imgUrl + " > "+file_path)   
                    count +=1 
                except:
                    count +=1 
                    continue
                
            if count == (1111+330+330):
                break
        except :
            continue
        
    
        
    time.sleep(5)
    driver.close()

# %%
search = "두부"
if not os.path.isdir(f"{search}/"):
    os.makedirs(f"{search}/")
    
get_img(search)
# Out:
#  54%|██████████████████████████████████████████▊                                     | 214/400 [08:32<07:25,  2.40s/it]

# %%
def get_img_ssg(query_text):
    count =88888
    
    driver = webdriver.Chrome()
    driver.get("https://www.ssg.com/")
    time.sleep(1) 

    elem = driver.find_element(By.CLASS_NAME,'inp_txt')
    elem.send_keys(query_text)
    elem.send_keys(Keys.RETURN)
    
    time.sleep(3)    

    page_number_li = driver.find_element(By.ID,'item_navi')
    page_number_len = len(page_number_li.find_elements(By.TAG_NAME , 'a'))+1
    print(page_number_len)
    page_number =  int(page_number_li.find_element(By.TAG_NAME,'strong').text)

    # 이미지 저장
    item_li = driver.find_element(By.CLASS_NAME,"cunit_lst_v").find_elements(By.CLASS_NAME,'i1')
    for idx in item_li:
        imgUrl = idx.get_attribute('src')
        file_path = f"{query_text}/" + query_text + "_" + str(count) + ".jpg"
        try :
                urllib.request.urlretrieve(imgUrl, file_path)
                count +=1 
        except :
            try :
                os.system("curl " + imgUrl + " > "+file_path)   
                count +=1 
            except:
                count +=1 
                continue
    
    if page_number_len+1 > 9:
        page_number_len = 9
        
    for page_idx in range(2,page_number_len+1):
        driver.get(f"https://www.ssg.com/search.ssg?target=all&query={query_text}&page={page_idx}")
        time.sleep(1) 
        
        item_li = driver.find_element(By.CLASS_NAME,"cunit_lst_v").find_elements(By.CLASS_NAME,'i1')
        
        for idx in item_li:
            imgUrl = idx.get_attribute('src')
            file_path = f"{query_text}/" + query_text + "_" + str(count) + ".jpg"
            try :
                    urllib.request.urlretrieve(imgUrl, file_path)
                    count +=1 
            except :
                try :
                    os.system("curl " + imgUrl + " > "+file_path)   
                    count +=1 
                except:
                    count +=1 
                    continue



    time.sleep(5)
    driver.close()

# %%
search_li = ["두부"]
for search in search_li :
    if not os.path.isdir(f"{search}/"):
        os.makedirs(f"{search}/")

    get_img_ssg(search)
# Out:
# 12
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Input In [4], in <cell line: 2>()
#       3 if not os.path.isdir(f"{search}/"):
#       4     os.makedirs(f"{search}/")
# ----> 6 get_img_ssg(search)
#
# Input In [3], in get_img_ssg(query_text)
#      20 item_li = driver.find_element(By.CLASS_NAME,"cunit_lst_v").find_elements(By.CLASS_NAME,'i1')
#      21 for idx in item_li:
# ---> 22     imgUrl = idx.get_attribute('src')
#      23     file_path = f"{query_text}/" + query_text + "_" + str(count) + ".jpg"
#      24     try :
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py:178, in WebElement.get_attribute(self, name)
#     176 if getAttribute_js is None:
#     177     _load_js()
# --> 178 attribute_value = self.parent.execute_script(
#     179     f"/* getAttribute */return ({getAttribute_js}).apply(null, arguments);", self, name
#     180 )
# ...

# %%
def get_img_ssg(query_text):
    count =0
    
    driver = webdriver.Chrome()
    driver.get("https://www.ssg.com/")
    time.sleep(1) 

    elem = driver.find_element(By.CLASS_NAME,'inp_txt')
    elem.send_keys(query_text)
    elem.send_keys(Keys.RETURN)
    
    time.sleep(3)
    
    item_li = driver.find_element(By.CLASS_NAME,"cunit_lst_v").find_elements(By.CLASS_NAME,'i1')
    # print(len(item_li))
    

    page_number_li = driver.find_element(By.ID,'item_navi')
    page_number_len = len(page_number_li.find_elements(By.TAG_NAME , 'a'))+1
    print(page_number_len)
    page_number =  int(page_number_li.find_element(By.TAG_NAME,'strong').text)

    
    while(1):
        print("현재 page : ",page_number)


        '''
        # 이미지 저장
        for idx in item_li:
            imgUrl = idx.get_attribute('src')
            file_path = f"{query_text}/" + query_text + "_" + str(count) + ".jpg"
            try :
                    urllib.request.urlretrieve(imgUrl, file_path)
                    count +=1 
            except :
                try :
                    os.system("curl " + imgUrl + " > "+file_path)   
                    count +=1 
                except:
                    count +=1 
                    continue
    ''' 
        # page 이동
        page_li = driver.find_element(By.ID,'item_navi').find_elements(By.TAG_NAME,'a') 
        for page_idx in page_li:
            page_check = int(page_idx.text)

            if page_check == (page_number+1):
                page_number = page_check 
                try : 
                    page_idx.click()
                except:
                    driver.execute_script("arguments[0].click();", page_idx)
                break
        


    time.sleep(5)
    driver.close()
